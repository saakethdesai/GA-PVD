# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
from matplotlib import font_manager

font_dirs = ['/Users/saadesa/Downloads/']
font_files = font_manager.findSystemFonts(fontpaths=font_dirs)

for font_file in font_files:
    font_manager.fontManager.addfont(font_file)

# set font
plt.rcParams['font.family'] = 'CMU Sans Serif'

# %%
timestep_minusone = np.loadtxt("1e-1.txt", skiprows=2)
timestep_minustwo = np.loadtxt("1e-2.txt", skiprows=2)
timestep_minusthree = np.loadtxt("1e-3.txt", skiprows=2)
timestep_minusfour = np.loadtxt("1e-4.txt", skiprows=2)

# %%
timestep_minustwo[:, -1]
# Out:
# array([  729.18003178,  -276.34956986,  -379.30407259,  -517.20413437,
#         -701.98148128,  -941.01301165, -1236.50240903, -1582.9896414 ,
#        -1966.55683978, -2367.12057132, -2763.37764261, -3138.03278162,
#        -3480.69682392, -3787.7057656 , -4060.11980451, -4301.52173445,
#        -4516.38579965, -4709.14700663, -4883.77363978, -5043.56757349,
#        -5191.13482921, -5328.50849903, -5457.28028518, -5578.73251154,
#        -5693.98838561, -5804.05192147, -5909.75413343, -6011.74978222,
#        -6110.57448262, -6206.67142689, -6300.33558892, -6391.63388988,
#        -6480.44686798, -6566.63812672, -6650.18725088, -6731.18178543,
#        -6809.7599228 , -6886.0693821 , -6960.24190693, -7032.38685184,
#        -7102.61672574, -7171.06011403, -7237.82211387, -7302.96428943,
#        -7366.52693551, -7428.543467  , -7489.06513535, -7548.18470287,
#        -7606.02486402, -7662.68455367, -7718.19459219, -7772.56320956,
# ...

# %%
# %matplotlib notebook

plt.figure(figsize=(10, 10))

plt.plot(timestep_minustwo[:, -1]/1000, lw=4, c="#d95f02")
plt.plot(timestep_minusthree[:, -1]/1000, lw=4, c="#7570b3")
plt.plot(timestep_minusfour[:, -1]/1000, lw=4, c="#1b9e77")

plt.yticks([-8, -6, -4, -2, 0])
plt.xlabel("Time(steps)*timestep", fontsize=24)
plt.ylabel("Free energy (x 10$^{3}$)", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.xlim([0, 130])
# Out:
# <img src="data:image/png;base64,..." width="1000">
# (array([-8, -6, -4, -2,  0]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# %matplotlib notebook

plt.figure(figsize=(11, 10))

base = timestep_minusthree[:, -1]

plt.plot((timestep_minustwo[:,-1] - base)*100/base, lw=4, c="#d95f02")
plt.plot((timestep_minusthree[:,-1] - base)*100/base, lw=4, c="#7570b3")
plt.plot((timestep_minusfour[:,-1] - base)*100/base, lw=4, c="#1b9e77")

#plt.yticks([-8, -6, -4, -2, 0])
plt.xlabel("Time(steps)*timestep", fontsize=24)
plt.ylabel("Percentage error in free energy", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
#plt.xlim([0, 130])
# Out:
# <img src="data:image/png;base64,..." width="1100">
# (array([-0.16, -0.14, -0.12, -0.1 , -0.08, -0.06, -0.04, -0.02,  0.  ,
#          0.02,  0.04]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
